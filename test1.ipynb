# %% [markdown]
# # Test_Kaggle_Hackathon
# ###

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
# Any results you write to the current directory are saved as output.

from keras.models import Model
from keras.layers import Dense, Embedding, Input
from keras.layers import LSTM, Bidirectional, GlobalMaxPool1D, Dropout
from keras.preprocessing import text, sequence
from keras.callbacks import EarlyStopping, ModelCheckpoint

max_features = 20000
maxlen = 100
# Out:
# Using TensorFlow backend.

# %%
#print(check_output(["ls", "../input"]).decode("utf8"))

train = pd.read_csv("train_csv/train.csv")
test = pd.read_csv("test_csv/test.csv")
train = train.sample(frac=1)

# %%
list_sentences_train = train["comment_text"].fillna("CVxTz").values
list_classes = ["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]
y = train[list_classes].values
list_sentences_test = test["comment_text"].fillna("CVxTz").values

# %%
tokenizer = text.Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(list(list_sentences_train))
list_tokenized_train = tokenizer.texts_to_sequences(list_sentences_train)
list_tokenized_test = tokenizer.texts_to_sequences(list_sentences_test)
X_t = sequence.pad_sequences(list_tokenized_train, maxlen=maxlen)
X_te = sequence.pad_sequences(list_tokenized_test, maxlen=maxlen)

# %%
def get_model():
    embed_size = 128
    inp = Input(shape=(maxlen, ))
    x = Embedding(max_features, embed_size)(inp)
    x = Bidirectional(LSTM(50, return_sequences=True))(x)
    x = GlobalMaxPool1D()(x)
    x = Dropout(0.1)(x)
    x = Dense(50, activation="relu")(x)
    x = Dropout(0.1)(x)
    x = Dense(6, activation="sigmoid")(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

    return model


model = get_model()
batch_size = 32
epochs = 2


file_path="weights_base_3epochs.best.hdf5"
checkpoint = ModelCheckpoint(file_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

early = EarlyStopping(monitor="val_loss", mode="min", patience=20)
 

callbacks_list = [checkpoint, early] #early
model.fit(X_t, y, batch_size=batch_size, epochs=3, validation_split=0.1, callbacks=callbacks_list)

model.load_weights(file_path)

y_test = model.predict(X_te)
# Out:
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/3
# 143584/143613 [============================>.] - ETA: 0s - loss: 0.0635 - acc: 0.9792
# Epoch 00001: val_loss improved from inf to 0.04839, saving model to weights_base_3epochs.best.hdf5
# 143613/143613 [==============================] - 1398s 10ms/step - loss: 0.0635 - acc: 0.9792 - val_loss: 0.0484 - val_acc: 0.9825
# Epoch 2/3
# 143584/143613 [============================>.] - ETA: 0s - loss: 0.0459 - acc: 0.9831
# Epoch 00002: val_loss improved from 0.04839 to 0.04685, saving model to weights_base_3epochs.best.hdf5
# 143613/143613 [==============================] - 1429s 10ms/step - loss: 0.0459 - acc: 0.9831 - val_loss: 0.0469 - val_acc: 0.9829
# Epoch 3/3
# 143584/143613 [============================>.] - ETA: 0s - loss: 0.0405 - acc: 0.9846
# Epoch 00003: val_loss did not improve
# 143613/143613 [==============================] - 1522s 11ms/step - loss: 0.0405 - acc: 0.9846 - val_loss: 0.0477 - val_acc: 0.9828

# %%
sample_submission = pd.read_csv("sample_submission_csv/sample_submission.csv")

sample_submission[list_classes] = y_test



sample_submission.to_csv("baseline_epoch3.csv", index=False)

# %% [markdown]
# ## Part 3: Vectorizing our dataset
#
# Instead of Vectorising using TfidfVectorizer, we could use COUNTVECTORIZER. But in CountVectorizer words which have high count and words with low count wont be discriminated, where in reality we want them to be differentiated. A word like "hairfall" should have more value than a word like "the".

# %%
# instantiate the vectorizer
# Vectorising
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(min_df=1,max_features=10000,ngram_range=(1,3),stop_words = 'english')

# %%
# learn training data vocabulary, then use it to create a document-term matrix

tfidf.fit(X_train)
X_train_dtm = tfidf.transform(X_train)

# %%
# equivalently: combine fit and transform into a single step
X_train_dtm = tfidf.fit_transform(X_train)

# %%
# examine the document-term matrix
X_train_dtm

# %%
# transform testing data (using fitted vocabulary) into a document-term matrix
X_test_dtm = tfidf.transform(X_test)
X_test_dtm

# %% [markdown]
# ## Part 4: Building and evaluating a model
#
# Models used SGD Classifer, Multinominal Naive Bayes and Logistic Regression
#
# >Stochastic Gradient Descent (SGD) is a simple yet very efficient approach to discriminative learning of linear classifiers under convex loss functions such as (linear) Support Vector Machines and Logistic Regression. Even though SGD has been around in the machine learning community for a long time, it has received a considerable amount of attention just recently in the context of large-scale learning.
#
# > The multinomial Naive Bayes classifier is suitable for classification with **discrete features** (e.g., word counts for text classification). The multinomial distribution normally requires integer feature counts. However, in practice, fractional counts such as tf-idf may also work.
#
#
#
# > Logistic regression, despite its name, is a **linear model for classification** rather than regression. Logistic regression is also known in the literature as logit regression, maximum-entropy classification (MaxEnt) or the log-linear classifier. In this model, the probabilities describing the possible outcomes of a single trial are modeled using a logistic function.

# %%
# Testing 
from sklearn.linear_model import SGDClassifier
lr = SGDClassifier(loss='log', penalty='l1', alpha=1e-06)

# %%
# %time lr.fit(X_train_dtm, y_train)

# %%
y_pred_class = lr.predict(X_test_dtm)

# %%
from sklearn import metrics
metrics.accuracy_score(y_test, y_pred_class)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-826e9f94336d> in <module>()
#       1 from sklearn import metrics
# ----> 2 metrics.accuracy_score(y_test, y_pred_class)
#
# NameError: name 'y_test' is not defined

# %%
X_test[4517],y_pred_class

# %%
y_test

# %%
# print message text for the false positives (ham incorrectly classified as spam)
X_test[y_test < y_pred_class]

# %%
X_test[763]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0adfd450cf20> in <module>()
# ----> 1 X_test[763]
#
# NameError: name 'X_test' is not defined

# %%
# print message text for the false negatives (spam incorrectly classified as ham)
X_test[y_test > y_pred_class]
# Out:
# 3132    LookAtMe!: Thanks for your purchase of a video...
# 684     Hi I'm sue. I am 20 years old and work as a la...
# 5368    IMPORTANT MESSAGE. This is a final contact att...
# 1893    CALL 09090900040 & LISTEN TO EXTREME DIRTY LIV...
# 4298    thesmszone.com lets you send free anonymous an...
# 4949    Hi this is Amy, we will be sending you a free ...
# 1073    Dear U've been invited to XCHAT. This is our f...
# 2821    INTERFLORA - It's not too late to order Inter...
# 1963    it to 80488. Your 500 free text messages are v...
# 2247    Hi ya babe x u 4goten bout me?' scammers getti...
# 4514    Money i have won wining number 946 wot do i do...
# Name: message, dtype: object

# %%
X_test[3132]
# Out:
# "LookAtMe!: Thanks for your purchase of a video clip from LookAtMe!, you've been charged 35p. Think you can do better? Why not send a video in a MMSto 32323."

# %%
# import and instantiate a Multinomial Naive Bayes model
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()

# %%
# train the model using X_train_dtm (timing it with an IPython "magic command")
# %time nb.fit(X_train_dtm, y_train)
# Out:
# Wall time: 10 ms
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
# make class predictions for X_test_dtm
y_pred_class = nb.predict(X_test_dtm)

# %%
# calculate accuracy of class predictions
from sklearn import metrics
metrics.accuracy_score(y_test, y_pred_class)
# Out:
# 0.82093663911845727

# %%
# print the confusion matrix
metrics.confusion_matrix(y_test, y_pred_class)
# Out:
# array([[1196,   12],
#        [  12,  173]])

# %%
# print message text for the false positives (ham misclassified as spam)
X_test[y_test < y_pred_class]
# Out:
# 136                I only haf msn. It's yijue@hotmail.com
# 5306    Ill be at yours in about 3 mins but look out f...
# 1615    Me sef dey laugh you. Meanwhile how's my darli...
# 694     Will purchase d stuff today and mail to you. D...
# 503                               Check with nuerologist.
# 5218            I accidentally brought em home in the box
# 4229                             Have you started in skye
# 5089                      What type of stuff do you sing?
# 2289                          Dont you have message offer
# 1497    I'm always on yahoo messenger now. Just send t...
# 3120                             Stop knowing me so well!
# 2890                               My battery is low babe
# Name: message, dtype: object

# %%
# print message text for the false negatives (client incorrectly classified as non client)
X_test[y_test > y_pred_class]
# Out:
# 1045    We know someone who you know that fancies you....
# 3530    Xmas & New Years Eve tickets are now on sale f...
# 1893    CALL 09090900040 & LISTEN TO EXTREME DIRTY LIV...
# 4298    thesmszone.com lets you send free anonymous an...
# 4949    Hi this is Amy, we will be sending you a free ...
# 1625    500 free text msgs. Just text ok to 80488 and ...
# 2821    INTERFLORA - It's not too late to order Inter...
# 2247    Hi ya babe x u 4goten bout me?' scammers getti...
# 4514    Money i have won wining number 946 wot do i do...
# Name: message, dtype: object

# %%
# example false negative
X_test[773]
# Out:
# 'mobile monthly cell services charges for att'

# %%
# calculate predicted probabilities for X_test_dtm (poorly calibrated)
y_pred_prob = nb.predict_proba(X_test_dtm)[:, 1]
y_pred_prob
# Out:
# array([  8.97567105e-01,   5.87126437e-01,   9.77139320e-01,
#          6.29794242e-01,   1.70750363e-01,   6.53000144e-01,
#          9.11693165e-01,   8.19610098e-01,   4.61506264e-01,
#          8.84190626e-01,   5.48769888e-01,   7.70334801e-01,
#          6.31593529e-01,   9.15613086e-01,   4.13413859e-01,
#          9.52851543e-01,   2.82954434e-03,   3.27568531e-01,
#          4.64356360e-01,   2.15699559e-01,   1.54564542e-01,
#         0.45347824,  0.70505409,  0.066349  ,  0.77802185,  0.47980508,
#         0.4220271 ,  0.64326944,  0.80517386,  0.82554195,  0.67239019,
#         0.33308005,  0.49718685,  0.74095744,  0.77048806,  0.48646424,
#         0.8251534 ,  0.17077807,  0.56768959,  0.73690339,  0.50302002,
#         0.62801015,  0.81661906,  0.92521198,  0.45757727,  0.88519681,
#         0.56227325,  0.89715975,  0.58767209,  0.89254583,  0.70641118,
#         0.64682199,  0.76686555,  0.90027893,  0.93016081,  0.67619358,
#         0.55919057,  0.45090595,  0.83283396,  0.83324553,  0.8136214 ,
#         0.79159255,  0.71562565,  0.85157766,  0.54557758,  0.50407308,
#         0.27930684,  0.52111798,  0.72923286,  0.58635533,  0.89384842,
#         0.37735459,  0.89153496,  0.48047527,  0.39805248,  0.10622662,
#         0.90904036,  0.62511254,  0.70904101,  0.43429203,  0.23430932,
#         0.68815758,  0.28743662,  0.59268362,  0.86377506,  0.27786556,
#         0.64386534,  0.72279549,  0.64487209,  0.85970806,  0.74507525,
#         0.27882127,  0.51340246,  0.3552673 ,  0.69639664,  0.64351524,
#         0.79746858,  0.64771913,  0.73108787,  0.88883737,  0.6798393 ,
#         0.73526893,  0.81416934,  0.3689969 ,  0.77319618,  0.75266595,
#         0.33605907,  0.6951375 ,  0.37397214,  0.6516682 ,  0.78837974,
#         0.80512542,  0.51318039,  0.99654182,  0.70650464,  0.64213942,
#         0.51893192,  0.6610896 ,  0.92521198,  0.51837352,  0.36727451,
#         0.86477815,  0.69227235,  0.87998027,  0.28055557,  0.34374378,
#         0.80036478,  0.72073515,  0.10795852,  0.68097943,  0.75425551,
#         0.73154122,  0.58704315,  0.72095977,  0.7100868 ,  0.70245062,
#         0.49128301,  0.74519223,  0.6102624 ,  0.72972109,  0.89118453,
#         0.43045318,  0.11805898,  0.75606295,  0.68864046,  0.76851041,
#         0.61090981,  0.78692437,  0.83485163,  0.8105055 ,  0.51780963,
#         0.61693118,  0.73622802,  0.34449524,  0.2893797 ,  0.8320281 ,
#         0.44007635,  0.65407365,  0.81840688,  0.67837734,  0.75446913,
#         0.66091387,  0.76567309,  0.3552673 ,  0.31783658,  0.57042237,
#         0.31599041,  0.3552673 ,  0.58011651,  0.32184763,  0.67418258,
#         0.89895623,  0.87578942,  0.44421263,  0.43585752,  0.71357675,
#         0.09922478,  0.90271965,  0.63003981,  0.45782783,  0.49891423,
#         0.41073828])

# %%
# calculate accuracy
metrics.accuracy_score(y_test, y_pred_class)
# Out:
# 0.83057851239669422

# %% [markdown]
# ## Part 5: Examining a model for further insight
#
# We will examine the our **trained Naive Bayes model** to calculate the approximate **"spamminess" of each token**.

# %%
# store the vocabulary of X_train
X_train_tokens = tfidf.get_feature_names()
len(X_train_tokens)
# Out:
# 10000

# %%
# examine the first 50 tokens
print(X_train_tokens[0:100000])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-0e19316228b4> in <module>()
#       1 # examine the first 50 tokens
# ----> 2 print(X_train_tokens[0:100000])
#
# NameError: name 'X_train_tokens' is not defined

# %%
X_train_dtm.todense()[0][0][0]
# Out:
# matrix([[ 0.,  0.,  0., ...,  0.,  0.,  0.]])

# %%
tfidf.vocabulary_
# Out:
# {u'reboot ym': 7018,
#  u'scold': 7403,
#  u'beautiful tomorrow': 1294,
#  u'wine kudi yarasu': 9586,
#  u'bringing': 1521,
#  u'wednesday': 9405,
#  u'box385 m6': 1484,
#  u'got hella': 3571,
#  u'anytime network mins': 1071,
#  u'reason brilliant': 7014,
#  u'free text messages': 3237,
#  u'cooking': 2164,
#  u'china': 1860,
#  u'w111wx': 9243,
#  u'kids': 4465,
#  u'kidz': 4469,
#  u'amt lt gt': 1037,
#  u'stamps country': 7997,
#  u'fone weekly new': 3146,
#  u'stylish simple pls': 8138,
#  u'dnt': 2624,
#  u'music': 5616,
#  u'dear school': 2451,
#  u'worse gastroenteritis takes': 9811,
#  u'yahoo': 9910,
#  u'couldn': 2206,
#  u'usher britney fml': 9112,
#  u'index wml id': 4193,
#  u'themob': 8440,
#  u'fone weekly': 3145,
#  u'award free': 1203,
#  u'hav nice': 3825,
#  u'wana': 9303,
#  u'pints': 6324,
#  u'argument wins': 1110,
#  u'callin': 1633,
#  u'want': 9307,
#  u'travel': 8732,
#  u'url gt': 9088,
#  u'wan2': 9300,
#  u'wrong': 9833,
#  u'yunny': 9981,
#  u'09066364311 collect': 212,
#  u'took place': 8692,
#  u'welcomes': 9447,
#  u'ur opinion': 9034,
#  u'fit': 3109,
#  u'screaming': 7418,
#  u'fix': 3110,
#  u'sky gamestar sky': 7754,
#  u'vouchers': 9228,
#  u'wish command': 9631,
#  u'wisdom teeth hidden': 9620,
#  u'carlos says': 1709,
#  u'latr wid cake': 4614,
#  u'walk like': 9285,
#  u'allah': 1000,
#  u'potential talent': 6728,
#  u'2day': 440,
#  u'nokia 8007 txting': 5785,
#  u'british hotels holiday': 1525,
#  u'sunny rays': 8179,
#  u'awaiting collection': 1200,
#  u'played mid week': 6508,
#  u'come tomorrow': 2050,
#  u'freemsg hey': 3256,
#  u'specially': 7953,
#  u'service': 7541,
#  u'ya love': 9902,
#  u'needed': 5679,
#  u'day word': 2430,
#  u'hiya': 3951,
#  u'real meaning': 6988,
#  u'charity polys zed': 1813,
#  u'knw dis lt': 4525,
#  u'feeling': 3052,
#  u'7th 6th': 709,
#  u'oh ya': 5906,
#  u'shd haf': 7607,
#  u'affairs': 941,
#  u'chat cheaper 08709222922': 1821,
#  u'going home': 3497,
#  u'wot hell': 9822,
#  u'read carefully heart': 6970,
#  u'today love': 8595,
#  u'believe wat': 1320,
#  u'txt chat': 8823,
#  u'sight maintain till': 7677,
#  u'tech': 8296,
#  u'oh ho time': 5901,
#  u'scream': 7416,
#  u'saying': 7381,
#  u'time sorry': 8535,
#  u'exmpel jsut': 2943,
#  u'll bring': 4809,
#  u'rich': 7210,
#  u'kick amp say': 4462,
#  u'rice': 7209,
#  u'holiday govt instituitions': 3989,
#  u'il send': 4140,
#  u'gud mrng': 3715,
#  u'weekly new': 9434,
#  u'gt lacs': 3671,
#  u'gt hours': 3668,
#  u'wan 2c': 9291,
#  u'lots': 4916,
#  u'lotr': 4915,
#  u'luv ignore dis': 5045,
#  u'sir hope': 7714,
#  u'nature': 5650,
#  u'customer service': 2325,
#  u'pls claim': 6534,
#  u'wish goodmorning amp': 9640,
#  u'lookin': 4878,
#  u'tomarrow': 8638,
#  u'eerie nokia': 2823,
#  u'sk38xh': 7740,
#  u'blonde': 1394,
#  u'fri': 3266,
#  u'frm': 3297,
#  u'feel guilty': 3045,
#  u'mila age23': 5295,
#  u'dave': 2390,
#  u'5000 await collection': 620,
#  u'cum': 2289,
#  u'09058091854': 165,
#  u'2wks': 467,
#  u'84128': 761,
#  u'pc http': 6194,
#  u'just 60p': 4375,
#  u'register sky opt': 7075,
#  u'academic': 871,
#  u'25p free': 426,
#  u'dis amt lt': 2596,
#  u'hai': 3759,
#  u'haf': 3751,
#  u'nope ll': 5812,
#  u'mobilesdirect free 08000938767': 5455,
#  u'hav': 3824,
#  u'mins half price': 5332,
#  u'pm esaplanade tonight': 6644,
#  u'coz man murdered': 2222,
#  u'morning dear': 5518,
#  u'cr9 5wb 0870': 2229,
#  u'having movies': 3839,
#  u'lor wat': 4893,
#  u'ur best': 8974,
#  u'5000 await': 619,
#  u'text shop': 8377,
#  u'life ends': 4695,
#  u'today think': 8611,
#  u'lor wan': 4892,
#  u'350 award number': 502,
#  u'haf enuff': 3752,
#  u'bath': 1276,
#  u'alwys touch good': 1007,
#  u'pay lt': 6187,
#  u'hurried plane': 4089,
#  u'69696': 668,
#  u'just come': 4383,
#  u'matches 09064019014': 5176,
#  u'3030 valid 12hrs': 482,
#  u'4742 9am 11pm': 560,
#  u'children need': 1854,
#  u'congratulations': 2118,
#  u'helloooo wake': 3892,
#  u'smashed': 7791,
#  u'flights speak live': 3127,
#  u'www smsco net': 9863,
#  u'outside like': 6029,
#  u'11 months entitled': 273,
#  u'lt gt lacs': 5007,
#  u'role': 7243,
#  u'let noe': 4679,
#  u'public holiday govt': 6868,
#  u'unlimited text': 8928,
#  u'3ss': 531,
#  u'oso': 6014,
#  u'man murdered lt': 5142,
#  u'macho': 5081,
#  u'minuts': 5350,
#  u'choice': 1865,
#  u'stays': 8038,
#  u'exact': 2926,
#  u'minute': 5339,
#  u'spk sn': 7966,
#  u'interview today': 4232,
#  u'going buy apartment': 3494,
#  u'4u': 580,
#  u'shirts': 7616,
#  u'boost': 1444,
#  u'match 08712300220 quoting': 5172,
#  u'wnt buy bmw': 9686,
#  u'address': 916,
#  u'want drive': 9313,
#  u'today text shop': 8608,
#  u'stomps': 8055,
#  u'working': 9791,
#  u'pm dps': 6641,
#  u'following': 3140,
#  u'spook 8007': 7978,
#  u'cash nitros': 1742,
#  u'admirer': 919,
#  u'dogging club unsubscribe': 2640,
#  u'surfing': 8205,
#  u'outs da': 6019,
#  u'oz guy kinda': 6061,
#  u'500 cash': 603,
#  u'skilgme tscs087147403231winawk age16': 7745,
#  u'bootydelious': 1448,
#  u'years': 9937,
#  u'professors': 6840,
#  u'jiu': 4320,
#  u'n9dx': 5629,
#  u'accidentally deleted': 883,
#  u'sorted': 7902,
#  u'didn': 2551,
#  u'retrieve': 7177,
#  u'receipt': 7023,
#  u'wiskey': 9659,
#  u'internet': 4230,
#  u'statement 07742676969 shows': 8026,
#  u'box 434': 1473,
#  u'duchess cornwall': 2767,
#  u'tomorrow yesterday today': 8655,
#  u'mobile content': 5432,
#  u'oni': 5951,
#  u'gud eveb': 3712,
#  u'spoken': 7976,
#  u'tv sky': 8799,
#  u'word draw 87066': 9768,
#  u'places hospitals medical': 6433,
#  u'doing ur': 2653,
#  u'auction send': 1176,
#  u'place preferably': 6402,
#  u'lunch lunch invited': 5038,
#  u'illness': 4145,
#  u'uk pobox36504w45wq': 8898,
#  u'service reply': 7553,
#  u'locations': 4847,
#  u'invite': 4238,
#  u'zoe': 9999,
#  u'buffet': 1561,
#  u'cash collect 09058099801': 1737,
#  u'printed': 6799,
#  u'08718738001 identifier code': 143,
#  u'gt married': 3680,
#  u'bstfrnd rply means': 1544,
#  u'voucher entered': 9224,
#  u'83049 cost': 754,
#  u'b4190604 pobox 7876150ppm': 1233,
#  u'5wb': 650,
#  u'5we': 653,
#  u'uk games': 8886,
#  u'tomorrow pls': 8651,
#  u'weekly comp': 9430,
#  u'awaiting': 1199,
#  u'arng dis': 1116,
#  u'tortilla': 8699,
#  u'new video phone': 5732,
#  u'1000 cash 5000': 245,
#  u'java games dload': 4298,
#  u'whats ur': 9483,
#  u'free auction send': 3195,
#  u'meet later': 5225,
#  u'5249': 629,
#  u'ur mail id': 9021,
#  u'cash 2000': 1727,
#  u'ok leave need': 5920,
#  u'west': 9477,
#  u'camera free mobile': 1661,
#  u'87131': 807,
#  u'wants': 9343,
#  u'photos': 6276,
#  u'doesn start march': 2635,
#  u'number asked': 5840,
#  u'situation': 7733,
#  u'08000839402 call2optout': 59,
#  u'36504 w45wq': 508,
#  u'wire3': 9613,
#  u'xmas reward waiting': 9887,
#  u'say slowly': 7378,
#  u'life gud': 4702,
#  u'car urgently': 1684,
#  u'cafe': 1594,
#  u'logo pic': 4857,
#  u'aiyo': 983,
#  u'experience reply': 2954,
#  u'savamob pobox84': 7363,
#  u'great week': 3643,
#  u'88888': 820,
#  u'txt music': 8827,
#  u'nothin': 5820,
#  u'hmv vouchers': 3963,
#  u'1winaweek': 374,
#  u'sum1': 8161,
#  u'schools': 7401,
#  u'textpod chance': 8402,
#  u'86688 let': 792,
#  u'traffic': 8724,
#  u'correct ans': 2179,
#  u'world': 9794,
#  u'draw txt music': 2729,
#  u'aathi love lot': 856,
#  u'told going': 8626,
#  u'dun disturb liao': 2773,
#  u'congrats year': 2116,
#  u'dracula 8007': 2719,
#  u'pongal': 6703,
#  u'win 200 summer': 9546,
#  u'com custcare 08715705022': 2014,
#  u'otside': 6015,
#  u'910': 838,
#  u'vettam set callertune': 9174,
#  u'gt times night': 3693,
#  u'special people': 7945,
#  u'lionp poly': 4778,
#  u'looking make': 4881,
#  u'09050002311': 153,
#  u'cared': 1698,
#  u'm26 3uz': 5060,
#  u'profit charity': 6844,
#  u'latest nokia phone': 4607,
#  u'pull': 6869,
#  u'rush': 7291,
#  u'admirer looking': 920,
#  u'dirty': 2593,
#  u'pobox84 m263uz 00': 6669,
#  u'request maangalyam alaipayuthe': 7160,
#  u'search postcode': 7429,
#  u'cream': 2240,
#  u'yoga': 9973,
#  u'bored': 1449,
#  u'plan liao': 6453,
#  u'send 86688 150p': 7481,
#  u'sch': 7392,
#  u'good hear': 3534,
#  u'08002888812 reply': 73,
#  u'way ur': 9394,
#  u'wish great': 9641,
#  u'mmmm fuck': 5392,
#  u'norm': 5813,
#  u'quiz wkly': 6909,
#  u'end reply end': 2843,
#  u'past': 6179,
#  u'pass': 6166,
#  u'clock': 1935,
#  u'sarasota': 7338,
#  u'silent spl character': 7684,
#  u'yup lor': 9989,
#  u'attempt contact txt': 1173,
#  u'800 cash collect': 713,
#  u'experience': 2951,
#  u'experience essential life': 2953,
#  u'followed': 3139,
#  u'gt charge felt': 3661,
#  u'oz let': 6062,
#  u'tc 150p': 8274,
#  u'yo yo': 9972,
#  u'free phone': 3224,
#  u'door': 2701,
#  u'smiling reading': 7813,
#  u'company': 2073,
#  u'tlp uk expressoffer': 8570,
#  u'great news': 3636,
#  u'sipix digital camera': 7712,
#  u'learn': 4640,
#  u'play send hmv': 6499,
#  u'direct ur': 2590,
#  u'huge': 4081,
#  u'hugs': 4082,
#  u'blonde new uk': 1396,
#  u'atlanta wish guys': 1165,
#  u'replied': 7116,
#  u'paper': 6144,
#  u'smiling': 7810,
#  u'saucy': 7355,
#  u'txt stop 80062': 8842,
#  u'plaid album': 6441,
#  u'dont want': 2698,
#  u'double mins txts': 2712,
#  u'shocking': 7619,
#  u'08712405022 1x150p': 123,
#  u'research': 7164,
#  u'18yrs': 357,
#  u'3hrs': 518,
#  u'pairs': 6107,
#  u'phone phone': 6257,
#  u'wine dine': 9580,
#  u'drpd deeraj': 2759,
#  u'happiness dat feel': 3801,
#  u'lose ur': 4900,
#  u'thinks special 09065174042': 8469,
#  u'felt inconsiderate nag': 3062,
#  u'deeraj': 2487,
#  u'wat time finish': 9365,
#  u'vijay going talk': 9193,
#  u'charges': 1808,
#  u'sure time': 8203,
#  u'time coming': 8518,
#  u'place like hour': 6392,
#  u'sorry battery died': 7882,
#  u'sell': 7474,
#  u'self': 7471,
#  u'win sony dvd': 9571,
#  u'age23 blonde new': 963,
#  u'hope enjoyed': 4019,
#  u'singles': 7707,
#  u'amp eve': 1013,
#  u'photo upload 08718730666': 6275,
#  u'sit aeroplane': 7726,
#  u'www tlp uk': 9869,
#  u'charged': 1805,
#  u'ugh': 8878,
#  u'3rd ur nature': 530,
#  u'sunny': 8178,
#  u'reading msg moral': 6976,
#  u'33 50 scotsman': 499,
#  u'3g': 512,
#  u'yes place town': 9957,
#  u'grand nature': 3619,
#  u'clos1 lvblefrnd jstfrnd': 1938,
#  u'31p': 492,
#  u'saturday stop go2': 7354,
#  u'connection': 2125,
#  u'bell': 1321,
#  u'acted': 895,
#  u'lose win': 4902,
#  u'wire3 net': 9614,
#  u'wer askd sit': 9472,
#  u'man week day': 5144,
#  u'awake': 1201,
#  u'dogging club': 2639,
#  u'budget': 1559,
#  u'yeah ll leave': 9924,
#  u'god crack': 3470,
#  u'wisdom teeth': 9619,
#  u'subs16 1win150ppmx3': 8143,
#  u'uk expressoffer ts': 8885,
#  u'cross ntwk mins': 2257,
#  u'sex dogging club': 7574,
#  u'infernal affairs': 4200,
#  u'den hop': 2512,
#  u'ur tear': 9051,
#  u'early': 2792,
#  u'knw': 4521,
#  u'lady': 4548,
#  u'various points': 9143,
#  u'parents': 6154,
#  u'friendship good': 3290,
#  u'couple': 2212,
#  u'txt xxx': 8851,
#  u'camera phone upgrade': 1665,
#  u'cos got': 2182,
#  u'vday': 9146,
#  u'phone upgrade': 6263,
#  u'mobile vary': 5446,
#  u'send stop': 7504,
#  u'customer place': 2320,
#  u'santa xmas eve': 7336,
#  u'lt gt seconds': 5016,
#  u'gaps holding hand': 3361,
#  u'statement 07742676969': 8025,
#  u'behave': 1315,
#  u'world easy': 9797,
#  u'box177 m221bp 2yr': 1481,
#  u'customer claim free': 2317,
#  u'work place': 9785,
#  u'wise man answer': 9625,
#  u'pobox36504w45wq': 6662,
#  u'use foreign': 9098,
#  u'po box 177': 6649,
#  u'11mths mobilesdirect': 277,
#  u'feel meet pain': 3048,
#  u'ok thanx': 5933,
#  u'cool ll text': 2169,
#  u'worth 500': 9816,
#  u'professors wer': 6841,
#  u'loving simple': 4975,
#  u'world easy win': 9798,
#  u'sending home': 7516,
#  u'500 cd': 605,
#  u'orange bluetooth mobiles': 5983,
#  u'8007 tone dracula': 725,
#  u'told earlier': 8625,
#  u'cabin pa said': 1593,
#  u'friends colleagues': 3283,
#  u'land': 4553,
#  u'came': 1648,
#  u'dey hurried': 2527,
#  u'plus minus': 6603,
#  u'www movietrivia': 9856,
#  u'number awarded 2000': 5843,
#  u'gud night': 3719,
#  u'claim easy just': 1901,
#  u'0808': 79,
#  u'll lt gt': 4826,
#  u'afternoon love goes': 950,
#  u'stockport sk38xh cost': 8053,
#  u'help 08702840625': 3895,
#  u'09056242159': 162,
#  u'wihtuot ayn mitsake': 9513,
#  u'video': 9176,
#  u'march ends': 5151,
#  u'twilight www': 8804,
#  u'free2day sexy': 3249,
#  u'don make': 2664,
#  u'free eerie': 3208,
#  u'credits': 2247,
#  u'didnt': 2555,
#  u'150p textoperator': 318,
#  u'makes': 5119,
#  u'thats': 8430,
#  u'confidence': 2105,
#  u'yan jiu': 9912,
#  u'www textpod net': 9867,
#  u'buy apartment chennai': 1577,
#  u'messaging sms': 5283,
#  u'w1j6hl ldn 18yrs': 9248,
#  u'tonight want real': 8688,
#  u'2end send stop': 443,
#  u've finished': 9149,
#  u'babe': 1238,
#  u'standard rates app': 8001,
#  u'baby': 1247,
#  u'reply sms video': 7140,
#  u'process': 6839,
#  u'make contact reveal': 5109,
#  u'threats sib': 8484,
#  u'educational': 2819,
#  u'line claim m95': 4761,
#  u'comedy': 2054,
#  u'intelligent': 4227,
#  u'closes': 1946,
#  u'pls relax ur': 6571,
#  u'realized': 6996,
#  u'81303': 745,
#  u'8007 titles ghost': 723,
#  u'ur draw 100': 8986,
#  u'place ur points': 6418,
#  u'dont miss': 2688,
#  u'need clean heart': 5664,
#  u'perfect': 6212,
#  u'world 7th': 9795,
#  u'day joy': 2408,
#  u'announcement freephone': 1046,
#  u'today birthday': 8590,
#  u'shall come pickle': 7593,
#  u'beautiful truth': 1295,
#  u'shortage': 7643,
#  u'melle oru': 5247,
#  u'books': 1443,
#  u'nokia 86021 hg': 5787,
#  u'durban': 2786,
#  u'love jen': 4941,
#  u'week competition draw': 9410,
#  u'instituitions closed including': 4225,
#  u'crazy frog': 2239,
#  u'purpose 500': 6875,
#  u'weekly comp just': 9431,
#  u'enjoyin': 2868,
#  u'today lucky': 8597,
#  u'code 3100': 1956,
#  u'mtmsg': 5593,
#  u'stomach': 8054,
#  u'meeting later': 5235,
#  u'wkly shopping spree': 9677,
#  u'50 sp': 594,
#  u'tonight': 8686,
#  u'knw wt real': 4527,
#  u'9am': 845,
#  u'08000839402 2stoptxt': 58,
#  u'3gbp network': 516,
#  u'08718727868 18 150ppm': 136,
#  u'9ae': 844,
#  u'slowly god': 7784,
#  u'aathi': 853,
#  u'free charge': 3204,
#  u'ard 10': 1099,
#  u'thanksgiving': 8427,
#  u'watching tv': 9379,
#  u'txt 1st': 8808,
#  u'maneesha like know': 5149,
#  u'want real': 9332,
#  u'instituitions': 4223,
#  u'jay': 4299,
#  u'jan': 4289,
#  u'tape': 8264,
#  u'konw waht rael': 4530,
#  u'moral 4get person': 5510,
#  u'collect 83355 ibhltd': 1983,
#  u'hey really': 3909,
#  u'dis lose': 2597,
#  u'fantasies 08707509020 just': 3003,
#  u'wap charge': 9346,
#  u'stuff': 8128,
#  u'murderer immediately reply': 5615,
#  u'charge felt inconsiderate': 1798,
#  u'wif darren': 9499,
#  u'guessing': 3730,
#  u'sonyericsson nokia': 7870,
#  u'help 08702840625 comuk': 3896,
#  u'8wp 150 ppm': 834,
#  u'dear hav': 2449,
#  u'number matches 09064019014': 5847,
#  u'texts 08712460324 10p': 8408,
#  u'honey': 4010,
#  u'com custcare': 2013,
#  u'havent got': 3832,
#  u'place midnight': 6394,
#  u'pls favor pls': 6551,
#  u'margaret hello girlfrnd': 5155,
#  u'news results daily': 5745,
#  u'goodmorning today': 3554,
#  u'theatre going': 8438,
#  u'hahaha': 3756,
#  u'12hrs 150ppm': 290,
#  u'09061209465 suprman': 174,
#  u'txts mobileupd8 08001950382': 8866,
#  u'win lose': 9562,
#  u'pa able': 6067,
#  u'87066 tscs www': 804,
#  u'newest': 5738,
#  u'register sky': 7074,
#  u'web': 9401,
#  u'new number': 5719,
#  u'din ur msg': 2579,
#  u'wen': 9450,
#  u'wer': 9470,
#  u'valid': 9124,
#  u'crack': 2231,
#  u'tooo simple': 8696,
#  u'16 stop': 337,
#  u'tick': 8493,
#  u'wkly shopping': 9676,
#  u'prize reward claim': 6827,
#  u'ya just': 9901,
#  u'collect 09058099801': 1980,
#  u'mobiles camera': 5449,
#  u'sweet morning welcomes': 8221,
#  u'today late': 8593,
#  u'jason says': 4295,
#  u'swimming': 8228,
#  u'2yr warranty 150ppm': 470,
#  u'amp fills gaps': 1016,
#  u'yrs': 9977,
#  u'notxt': 5822,
#  u'gudnite tc': 3723,
#  u'places': 6431,
#  u'problem': 6836,
#  u'free yes': 3247,
#  u'gm gn ge': 3461,
#  u'lately': 4584,
#  u'details': 2521,
#  u'nokias poly charity': 5806,
#  u'win 40gb': 9550,
#  u'status': 8030,
#  u'msg reply': 5571,
#  u'amp nice sleep': 1024,
#  u'mate': 5178,
#  u'worth': 9813,
#  u'0808 145': 80,
#  u'spook mob': 7980,
#  u'math': 5184,
#  u'pandy': 6117,
#  u'gr8 message': 3611,
#  u'chance reality fantasy': 1780,
#  u'mob halloween collection': 5407,
#  u'worth discount': 9818,
#  u'textoperator': 8398,
#  u'great princess': 3640,
#  u'msg recd cust': 5570,
#  u'music 87066 ts': 5619,
#  u'darlin ive': 2370,
#  u'happy new year': 3809,
#  u'remains bro bros': 7090,
#  u'award number matches': 1205,
#  u'wasn bad': 9356,
#  u'custcare 08712405020': 2308,
#  u'custcare 08712405022': 2309,
#  u'bro': 1529,
#  u'coins': 1972,
#  u'expressoffer': 2970,
#  u'net custcare 08712405020': 5688,
#  u'morning plz': 5520,
#  u'sexy st': 7581,
#  u'cuddle': 2287,
#  u'erm': 2891,
#  u'storming msg': 8102,
#  u'sms 1st ur': 7822,
#  u'call2optout 674': 1605,
#  u'god picked flower': 3479,
#  u'appreciate': 1086,
#  u'urgent mobile': 9077,
#  u'tomorrow going theatre': 8648,
#  u'sunday holiday work': 8174,
#  u'row w1jhl': 7258,
#  u'cs savamob pobox84': 2276,
#  u'coffee': 1968,
#  u'safe': 7306,
#  u'roommate': 7248,
#  u'spoke maneesha': 7974,
#  u'000 bonus caller': 5,
#  u'know details': 4493,
#  u'2000 cash': 385,
#  u'123 congratulations week': 288,
#  u'stop extra': 8072,
#  u'stop frnd': 8074,
#  u'chance win': 1781,
#  u'hey mr': 3908,
#  u'greet westlife': 3649,
#  u'50 increments help08718728876': 587,
#  u'identifier code': 4126,
#  u'way railway': 9391,
#  u'800 redeemed points': 717,
#  u'john': 4331,
#  u'8007 txting': 726,
#  u'won guaranteed 1000': 9708,
#  u'sexy buns': 7578,
#  u'police arrested': 6682,
#  u'apps class': 1089,
#  u'later lt gt': 4591,
#  u'150p 18': 311,
#  u'send dis msg': 7486,
#  u'germany': 3409,
#  u'gudnite tc practice': 3724,
#  u'day know': 2410,
#  u'w111wx 50': 9244,
#  u'await collection': 1195,
#  u'po box385 m6': 6654,
#  u'aunt': 1181,
#  u'new years': 5736,
#  u'send postcard': 7501,
#  u'vry urgent hv': 9241,
#  u'line rental camcorder': 4764,
#  u'outside izzit': 6028,
#  u'pls send correct': 6579,
#  u'miss ya': 5371,
#  u'runs': 7290,
#  u'secretary': 7444,
#  u'cash 100': 1723,
#  u'buy space': 1581,
#  u'hours answer': 4055,
#  u'uk guys': 8888,
#  u'away': 1223,
#  u'tee hee': 8300,
#  u'self limiting illness': 7473,
#  u'place nuther time': 6399,
#  u'seeing gud': 7455,
#  u'150p mtmsg': 316,
#  u'tone': 8656,
#  u'sent lt gt': 7531,
#  u'massive': 5168,
#  u'08000839402 call2optout n9dx': 61,
#  u'priscilla': 6800,
#  u'decimal gt lt': 2474,
#  u'sorry im': 7890,
#  u'rental 12 mths': 7104,
#  u'box 326': 1471,
#  u'information': 4205,
#  u'beer vodka scotch': 1310,
#  u'technical support': 8298,
#  u'mobile awarded 000': 5429,
#  u'throat': 8486,
#  u'belovd swtheart': 1324,
#  u'girl margaret': 3446,
#  u'transfr': 8729,
#  u'let ask': 4675,
#  u'send free': 7488,
#  u'sex 30': 7571,
#  u'hand': 3777,
#  u'w1jhl': 9249,
#  u'text pix 8552': 8375,
#  u'time wan come': 8545,
#  u'min': 5298,
#  u'new tone': 5726,
#  u'thanks': 8420,
#  u'latest camera': 4596,
#  u'forwarded 21870000 hi': 3178,
#  u'forgot did': 3167,
#  u'mis': 5356,
#  u'cool': 2167,
#  u'night': 5757,
#  u'world running': 9801,
#  u'home tired come': 4004,
#  u'born': 1451,
#  u'msg wrnog': 5576,
#  u'yes 85023 savamob': 9947,
#  u'ass south': 1159,
#  u'fine absolutly fine': 3094,
#  u'asking': 1153,
#  u'ranjith cal': 6943,
#  u'm227xy': 5058,
#  u'08000839402 call2optout lf56': 60,
#  u'gud mrng dear': 3716,
#  u'thanks ringtone order': 8426,
#  u'come home': 2034,
#  u'ipod mp3': 4258,
#  u'congratulations thanks good': 2120,
#  u'poly www': 6694,
#  u'clos1 lvblefrnd': 1937,
#  u'love lot': 4944,
#  u'congrats year special': 2117,
#  u'service announcement premier': 7544,
#  u'txt word draw': 8849,
#  u'08719180248': 144,
#  u'like rain': 4736,
#  u'pandy joined 4w': 6119,
#  u'rael friendship im': 6924,
#  u'go2 notxt': 3466,
#  u'test': 8348,
#  u'wana meet': 9304,
#  u'free delivery': 3205,
#  u'update': 8948,
#  u'blah blah': 1380,
#  u'normally': 5818,
#  u'press games': 6777,
#  u'place later': 6388,
#  u'txt82228': 8852,
#  u'dear voucher holder': 2458,
#  u'frnd': 3300,
#  u'gift speak': 3430,
#  u'code 3100 standard': 1957,
#  u'claim reward': 1912,
#  u'pain feel': 6098,
#  u'gud': 3711,
#  u'turns': 8789,
#  u'phones half': 6269,
#  u'guy': 3733,
#  u'project centre': 6846,
#  u'cost': 2188,
#  u'wife knew time': 9508,
#  u'answer easy questions': 1057,
#  u'really bad': 6999,
#  u'shared': 7604,
#  u'discount vouchers': 2607,
#  u'teaches': 8285,
#  u'teacher': 8284,
#  u'sending': 7515,
#  u'surprise waiting': 8208,
#  u'ur friends just': 8996,
#  u'434': 550,
#  u'extra': 2973,
#  u'plz number shows': 6627,
#  u'1000 cash': 243,
#  u'ends tomorrow': 2852,
#  u'awarded 500': 1217,
#  u'wan meet': 9296,
#  u'joy father john': 4351,
#  u'fixed': 3111,
#  u'ibh': 4108,
#  u'know country liverpool': 4492,
#  u'wake gt': 9278,
#  u'txt rate': 8836,
#  u'texted': 8396,
#  u'chip': 1863,
#  u'pobox84 m26': 6666,
#  u'pizza lol': 6363,
#  u'3lp 50': 522,
#  u'lt gt times': 5018,
#  u'write msg dictionary': 9829,
#  u'cw25wx': 2345,
#  u'relax children': 7081,
#  u'ldnw15h 150p mtmsgrcvd18': 4637,
#  u'foreign stamps country': 3157,
#  u'lar tot': 4573,
#  u'gving yuo': 3746,
#  u'approx': 1087,
#  u'ended': 2845,
#  u'tablets': 8241,
#  u'01223585334 cum wan': 19,
#  u'no1': 5775,
#  u'fantastic surprise': 3005,
#  u'mitsake': 5380,
#  u'stockport sk38xh': 8052,
#  u'cs po': 2271,
#  u'noe': 5778,
#  u'completely stop': 2082,
#  u'100 cash': 225,
#  u'yeah able': 9921,
#  u'like ok': 4732,
#  u'msgrcvdhg suite342 2lands': 5582,
#  u'drop': 2752,
#  u'wid ur mates': 9494,
#  u'yeah': 9920,
#  u'like fun': 4724,
#  u'year': 9928,
#  u'yarasu dhina vaazhthukkal': 9917,
#  u'text free': 8362,
#  u'delivery 28days': 2506,
#  u'wonderful hope': 9721,
#  u'blind': 1391,
#  u'ring': 7217,
#  u'tomorrow': 8646,
#  u'break win': 1510,
#  u'caught': 1753,
#  u'loses person': 4905,
#  u'gastroenteritis': 3372,
#  u'hsbc': 4072,
#  u'secs ring 02073162414': 7447,
#  u'dun like ah': 2776,
#  u'net login 3qxj9': 5690,
#  u'po box 434': 6650,
#  u'09061213237 landline': 177,
#  u'self limiting': 7472,
#  u'pizza know': 6361,
#  u'world 7th 6th': 9796,
#  u'mrt': 5552,
#  u'send free sms': 7489,
#  u'box95qu': 1489,
#  u'sunshine quiz': 8182,
#  u'ones bcoz': 5948,
#  u'entered receipt correct': 2877,
#  u'awarded sipix': 1221,
#  u'love hope': 4940,
#  u'inside': 4220,
#  u'outta way': 6042,
#  u'meds just vomit': 5218,
#  u'number 09066364311 collect': 5839,
#  u'colours': 2011,
#  u'landline': 4556,
#  u'hurts': 4096,
#  u'izzit': 4283,
#  u'msg dictionary mode': 5559,
#  u'margaret hello': 5154,
#  u'jeans': 4308,
#  u'opt reply reveal': 5973,
#  u'murderer coz': 5612,
#  u'wont able': 9744,
#  u'got persons': 3586,
#  u'collect 83355': 1982,
#  u'28days cs': 434,
#  u'wondering wont': 9737,
#  u'going talk': 3504,
#  u'plaid album quite': 6442,
#  u've invited xchat': 9152,
#  u'pls family': 6548,
#  u'0800 1956669 text': 54,
#  u'dad went': 2360,
#  u'cs sae': 2273,
#  u'fool': 3148,
#  u'pink panther': 6322,
#  u'develop': 2525,
#  u'food': 3147,
#  u'action 80608 www': 898,
#  u'atm sms': 1167,
#  u'text age followed': 8357,
#  u'post office children': 6718,
#  u'wish come anymore': 9630,
#  u'greetings': 3651,
#  u'death': 2466,
#  u'wonderful okors': 9723,
#  u'gonna': 3516,
#  u'amp': 1010,
#  u'amt': 1035,
#  u'favour pls convey': 3034,
#  u'conducts': 2103,
#  u'happy sad': 3812,
#  u'disturb liao': 2617,
#  u'07 11 04': 37,
#  u'cash holiday flights': 1739,
#  u'entry textpod chance': 2887,
#  u'selected receivea': 7464,
#  u'know god created': 4497,
#  u'exciting': 2931,
#  u'service know': 7551,
#  u'savamob offers mobile': 7362,
#  u'boy late': 1491,
#  u'subscriber ur': 8149,
#  u'people special sight': 6211,
#  u'wonderful plans': 9725,
#  u'adult singles': 926,
#  u'start': 8005,
#  u'stars': 8004,
#  u'won 800': 9703,
#  u'tone charity': 8661,
#  u'600': 657,
#  u'sat wer': 7343,
#  u'unlimited text free': 8930,
#  u'played original': 6509,
#  u'poor': 6707,
#  u'60p': 661,
#  u'heart love mind': 3865,
#  u'31p msg': 493,
#  u'pool': 6706,
#  u'really just': 7003,
#  u'know land line': 4500,
#  u'freephone 0808': 3260,
#  u'freephone 0800': 3258,
#  u'send dis': 7485,
#  u'month': 5491,
#  u'face book': 2983,
#  u'wml': 9681,
#  u'contact reveal thinks': 2139,
#  u'ni8 dear slp': 5750,
#  u'decide': 2470,
#  u'think gonna': 8455,
#  u'ringtone reply real': 7228,
#  u'yuo raed wihtuot': 9986,
#  u'enjoy ur': 2866,
#  ...}

# %% [markdown]
# However, the vectorizer is worth tuning, just like a model is worth tuning! Here are a few parameters that you might want to tune:
#
# - **stop_words:** string {'english'}, list, or None (default)
#     - If 'english', a built-in stop word list for English is used.
#     - If a list, that list is assumed to contain stop words, all of which will be removed from the resulting tokens.
#     - If None, no stop words will be used.

# %% [markdown]
# - **ngram_range:** tuple (min_n, max_n), default=(1, 1)
#     - The lower and upper boundary of the range of n-values for different n-grams to be extracted.
#     - All values of n such that min_n <= n <= max_n will be used.

# %% [markdown]
# - **max_df:** float in range [0.0, 1.0] or int, default=1.0
#     - When building the vocabulary, ignore terms that have a document frequency strictly higher than the given threshold (corpus-specific stop words).
#     - If float, the parameter represents a proportion of documents.
#     - If integer, the parameter represents an absolute count.

# %% [markdown]
# - **min_df:** float in range [0.0, 1.0] or int, default=1
#     - When building the vocabulary, ignore terms that have a document frequency strictly lower than the given threshold. (This value is also called "cut-off" in the literature.)
#     - If float, the parameter represents a proportion of documents.
#     - If integer, the parameter represents an absolute count.

# %% [markdown]
# **Guidelines for tuning TFIDFVectorizer:**
#
# - Use your knowledge of the **problem** and the **text**, and your understanding of the **tuning parameters**, to help you decide what parameters to tune and how to tune them.
# - **Experiment**, and let the data tell you the best approach!
